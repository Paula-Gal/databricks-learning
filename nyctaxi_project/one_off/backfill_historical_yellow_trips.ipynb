# %%
import urllib.request 
# URL lib request is a built in Python module that's used to open and read URL's
# Allows to download data files over HTTP or HTTPS and it's commonly used for basic web requests
# such as fetching APIs or downloading files without needing external libraries

import shutil
# For performing high lvel operations like copying, moving, and deleting files and directories

import os
# Allows to create a directory

# %%
url = "https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2025-01.parquet"

response = urllib.request.urlopen(url)

dir_path = "/Volumes/nyctaxi/00_landing/data_sources/nyctaxi_yellow/2025-01"

os.makedirs(dir_path, exist_ok=True)

local_path = dir_path + "/yellow_tripdata_2025-01.parquet"

with open(local_path, 'wb') as f:
    shutil.copyfileobj(response, f)

# %%
dates_to_process = ['2025-01', '2025-02', '2025-03', '2025-04', '2025-05', '2025-06']

for date in dates_to_process:
    url = f"https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_{date}.parquet"

    response = urllib.request.urlopen(url)

    dir_path = f"/Volumes/nyctaxi/00_landing/data_sources/nyctaxi_yellow/{date}"

    os.makedirs(dir_path, exist_ok=True)

    local_path = f"{dir_path}/yellow_tripdata_{date}.parquet"

    with open(local_path, 'wb') as f:
        shutil.copyfileobj(response, f)
